# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">CARS - G1 Group Work</p>

# %% [markdown]
# # Analyze df1 (cars1)

# %%
import pandas as pd
import numpy as np

# %%
cars1 = pd.read_csv("cars1.csv")
df1 = cars1.copy()

df1
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 193  24.0          6           200         81    3012          17.6     76
# 194  22.5          6           232         90    3085          17.6     76
# 195  29.0          4            85         52    2035          22.2     76
# 196  24.5          4            98         60    2164          22.1     76
# 197  29.0          4            90         70    1937          14.2     76
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198 entries, 0 to 197
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           198 non-null    float64
#  1   cylinders     198 non-null    int64
#  2   displacement  198 non-null    int64
#  3   horsepower    198 non-null    object
#  4   weight        198 non-null    int64
#  5   acceleration  198 non-null    float64
#  6   model         198 non-null    int64
#  7   origin        198 non-null    int64
#  8   car           198 non-null    object
#  9   Unnamed: 9    0 non-null      float64
#  10  Unnamed: 10   0 non-null      float64
#  11  Unnamed: 11   0 non-null      float64
#  12  Unnamed: 12   0 non-null      float64
#  13  Unnamed: 13   0 non-null      float64
# dtypes: float64(7), int64(5), object(2)
# memory usage: 21.8+ KB

# %%
df1.drop(columns = ["Unnamed: 9", "Unnamed: 10", "Unnamed: 11", "Unnamed: 12", "Unnamed: 13"], inplace=True)
df1
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 193  24.0          6           200         81    3012          17.6     76
# 194  22.5          6           232         90    3085          17.6     76
# 195  29.0          4            85         52    2035          22.2     76
# 196  24.5          4            98         60    2164          22.1     76
# 197  29.0          4            90         70    1937          14.2     76
#
#      origin                        car
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198 entries, 0 to 197
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           198 non-null    float64
#  1   cylinders     198 non-null    int64
#  2   displacement  198 non-null    int64
#  3   horsepower    198 non-null    object
#  4   weight        198 non-null    int64
#  5   acceleration  198 non-null    float64
#  6   model         198 non-null    int64
#  7   origin        198 non-null    int64
#  8   car           198 non-null    object
# dtypes: float64(2), int64(5), object(2)
# memory usage: 14.0+ KB

# %% [markdown]
# # Analyze df2 (cars2)

# %%
cars2 = pd.read_csv("cars2.csv")
df2 = cars2.copy()

df2
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    33.0          4            91         53    1795          17.4     76
# 1    20.0          6           225        100    3651          17.7     76
# 2    18.0          6           250         78    3574          21.0     76
# 3    18.5          6           250        110    3645          16.2     76
# 4    17.5          6           258         95    3193          17.8     76
# ..    ...        ...           ...        ...     ...           ...    ...
# 195  27.0          4           140         86    2790          15.6     82
# 196  44.0          4            97         52    2130          24.6     82
# 197  32.0          4           135         84    2295          11.6     82
# 198  28.0          4           120         79    2625          18.6     82
# 199  31.0          4           119         82    2720          19.4     82
#
#      origin                 car
# 0         3         honda civic
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           200 non-null    float64
#  1   cylinders     200 non-null    int64
#  2   displacement  200 non-null    int64
#  3   horsepower    200 non-null    object
#  4   weight        200 non-null    int64
#  5   acceleration  200 non-null    float64
#  6   model         200 non-null    int64
#  7   origin        200 non-null    int64
#  8   car           200 non-null    object
# dtypes: float64(2), int64(5), object(2)
# memory usage: 14.2+ KB

# %% [markdown]
# # Concat df1 and df2

# %%
df = pd.concat([df1, df2])
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 195  27.0          4           140         86    2790          15.6     82
# 196  44.0          4            97         52    2130          24.6     82
# 197  32.0          4           135         84    2295          11.6     82
# 198  28.0          4           120         79    2625          18.6     82
# 199  31.0          4           119         82    2720          19.4     82
#
#      origin                        car
# ...

# %%
df.sample(10)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  model  \
# 56   20.2          6           200        85.0    2965          15.8     78
# 38   25.5          4           140        89.0    2755          15.8     77
# 179  31.0          4            91        68.0    1970          17.6     82
# 72   15.0          8           304       150.0    3892          12.5     72
# 19   30.0          4           111        80.0    2155          14.8     77
# 106  12.0          8           350       180.0    4499          12.5     73
# 34   16.0          6           225       105.0    3439          15.5     71
# 100  18.0          6           250        88.0    3021          16.5     73
# 177  23.0          4           115        95.0    2694          15.0     75
# 48   18.0          6           250        88.0    3139          14.5     71
#
#      origin                        car
# 56        1       ford fairmont (auto)
# 38        1        ford mustang ii 2+2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 398 entries, 0 to 199
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    int64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model         398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car           398 non-null    object
# dtypes: float64(2), int64(5), object(2)
# memory usage: 31.1+ KB

# %%
df.describe(include="O").T
# Out:
#            count unique         top freq
# horsepower   398     94         150   22
# car          398    305  ford pinto    6

# %%
df.horsepower.unique()
# Out:
# array(['130', '165', '150', '140', '198', '220', '215', '225', '190',
#        '170', '160', '95', '97', '85', '88', '46', '87', '90', '113',
#        '200', '210', '193', '?', '100', '105', '175', '153', '180', '110',
#        '72', '86', '70', '76', '65', '69', '60', '80', '54', '208', '155',
#        '112', '92', '145', '137', '158', '167', '94', '107', '230', '49',
#        '75', '91', '122', '67', '83', '78', '52', '61', '93', '148',
#        '129', '96', '71', '98', '115', '53', '81', '79', '120', '152',
#        '102', '108', '68', '58', '149', '89', '63', '48', '66', '139',
#        '103', '125', '133', '138', '135', '142', '77', '62', '132', '84',
#        '64', '74', '116', '82'], dtype=object)

# %%
df[df.horsepower == '?']
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 32   25.0          4            98          ?    2046          19.0     71
# 126  21.0          6           200          ?    2875          17.0     74
# 132  40.9          4            85          ?    1835          17.3     80
# 138  23.6          4           140          ?    2905          14.3     80
# 156  34.5          4           100          ?    2320          15.8     81
# 176  23.0          4           151          ?    3035          20.5     82
#
#      origin                   car
# 32        1            ford pinto
# 126       1         ford maverick
# 132       2  renault lecar deluxe
# 138       1    ford mustang cobra
# 156       2           renault 18i
# 176       1        amc concord dl

# %%
df[df.car == 'ford pinto']
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 32   25.0          4            98          ?    2046          19.0     71
# 112  19.0          4           122         85    2310          18.5     73
# 130  26.0          4           122         80    2451          16.5     74
# 168  23.0          4           140         83    2639          17.0     75
# 174  18.0          6           171         97    2984          14.5     75
# 8    26.5          4           140         72    2565          13.6     76
#
#      origin         car
# 32        1  ford pinto
# 112       1  ford pinto
# 130       1  ford pinto
# 168       1  ford pinto
# 174       1  ford pinto
# 8         1  ford pinto

# %%
df[df.car == 'ford maverick']
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 17   21.0          6           200         85    2587          16.0     70
# 100  18.0          6           250         88    3021          16.5     73
# 126  21.0          6           200          ?    2875          17.0     74
# 155  15.0          6           250         72    3158          19.5     75
# 193  24.0          6           200         81    3012          17.6     76
#
#      origin            car
# 17        1  ford maverick
# 100       1  ford maverick
# 126       1  ford maverick
# 155       1  ford maverick
# 193       1  ford maverick

# %%
df[df.car == 'renault lecar deluxe']
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 132  40.9          4            85          ?    1835          17.3     80
#
#      origin                   car
# 132       2  renault lecar deluxe

# %%
df[df.car == 'ford mustang cobra']
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 138  23.6          4           140          ?    2905          14.3     80
#
#      origin                 car
# 138       1  ford mustang cobra

# %%
df[df.car == 'renault 18i']
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 156  34.5          4           100          ?    2320          15.8     81
#
#      origin          car
# 156       2  renault 18i

# %%
df[df.car == 'amc concord dl']
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 176  23.0          4           151          ?    3035          20.5     82
#
#      origin             car
# 176       1  amc concord dl

# %%
df["horsepower"] = df.horsepower.replace("?", np.nan).astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 398 entries, 0 to 199
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    int64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model         398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car           398 non-null    object
# dtypes: float64(3), int64(5), object(1)
# memory usage: 31.1+ KB

# %%
df.describe(include="O").T
# Out:
#     count unique         top freq
# car   398    305  ford pinto    6

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  model  \
# 0    18.0          8           307       130.0    3504          12.0     70
# 1    15.0          8           350       165.0    3693          11.5     70
# 2    18.0          8           318       150.0    3436          11.0     70
# 3    16.0          8           304       150.0    3433          12.0     70
# 4    17.0          8           302       140.0    3449          10.5     70
# ..    ...        ...           ...         ...     ...           ...    ...
# 195  27.0          4           140        86.0    2790          15.6     82
# 196  44.0          4            97        52.0    2130          24.6     82
# 197  32.0          4           135        84.0    2295          11.6     82
# 198  28.0          4           120        79.0    2625          18.6     82
# 199  31.0          4           119        82.0    2720          19.4     82
#
#      origin                        car
# ...

# %%
df.describe().T
# Out:
#               count         mean         std     min       25%     50%  \
# mpg           398.0    23.514573    7.815984     9.0    17.500    23.0
# cylinders     398.0     5.454774    1.701004     3.0     4.000     4.0
# displacement  398.0   193.427136  104.268683    68.0   104.250   148.5
# horsepower    392.0   104.469388   38.491160    46.0    75.000    93.5
# weight        398.0  2970.424623  846.841774  1613.0  2223.750  2803.5
# acceleration  398.0    15.568090    2.757689     8.0    13.825    15.5
# model         398.0    76.010050    3.697627    70.0    73.000    76.0
# origin        398.0     1.572864    0.802055     1.0     1.000     1.0
#
#                    75%     max
# mpg             29.000    46.6
# cylinders        8.000     8.0
# displacement   262.000   455.0
# horsepower     126.000   230.0
# weight        3608.000  5140.0
# acceleration    17.175    24.8
# model           79.000    82.0
# origin           2.000     3.0

# %%
df.nunique()
# Out:
# mpg             129
# cylinders         5
# displacement     81
# horsepower       93
# weight          351
# acceleration     95
# model            13
# origin            3
# car             305
# dtype: int64

# %% [markdown]
# ## 1) Which are the first five cars with the lowest average mpg?

# %%
df.groupby("car")["mpg"].mean().sort_values().head(10)
# Out:
# car
# hi 1200d                     9.0
# chevy c20                   10.0
# ford f250                   10.0
# dodge d200                  11.0
# oldsmobile omega            11.0
# mercury marquis             11.0
# dodge monaco (sw)           12.0
# mercury marquis brougham    12.0
# oldsmobile vista cruiser    12.0
# buick electra 225 custom    12.0
# Name: mpg, dtype: float64

# %% [markdown]
# ## 2) Which are the first five cars with the highest average mpg?

# %%
df.groupby("car")["mpg"].mean().sort_values().tail(10)
# Out:
# car
# plymouth champ                     39.0
# toyota starlet                     39.1
# datsun b210 gx                     39.4
# renault lecar deluxe               40.9
# volkswagen rabbit custom diesel    43.1
# vw dasher (diesel)                 43.4
# vw pickup                          44.0
# vw rabbit c (diesel)               44.3
# honda civic 1500 gl                44.6
# mazda glc                          46.6
# Name: mpg, dtype: float64

# %% [markdown]
# ## 3) Find the mean meadian and standard deviation of horsepower of the cars with 4 cylinders.

# %%
# First of all, change dtype of horsepower to float

# df["horsepower"] = df.horsepower.replace("?", np.nan).astype(float)

# %%
df[df["cylinders"] == 4]["horsepower"].agg(["mean", "median", "std"])
# Out:
# mean      78.281407
# median    78.000000
# std       14.523099
# Name: horsepower, dtype: float64

# %% [markdown]
# ## 4) Find the mean meadian and standard deviation of horsepower of the cars based on the number of their cylinders.

# %%
df.horsepower.agg(["mean", "median", "std"])
# Out:
# mean      104.469388
# median     93.500000
# std        38.491160
# Name: horsepower, dtype: float64

# %%
df.groupby("cylinders")["horsepower"].agg(["mean", "median", "std"])
# Out:
#                  mean  median        std
# cylinders
# 3           99.250000    98.5   8.301606
# 4           78.281407    78.0  14.523099
# 5           82.333333    77.0  18.583146
# 6          101.506024   100.0  14.310472
# 8          158.300971   150.0  28.453552

# %%
df1.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0          8           307        130    3504          12.0     70
# 1  15.0          8           350        165    3693          11.5     70
# 2  18.0          8           318        150    3436          11.0     70
# 3  16.0          8           304        150    3433          12.0     70
# 4  17.0          8           302        140    3449          10.5     70
#
#    origin                        car
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df4 = df.iloc[:, [3,5]]
df4
# Out:
#      horsepower  acceleration
# 0         130.0          12.0
# 1         165.0          11.5
# 2         150.0          11.0
# 3         150.0          12.0
# 4         140.0          10.5
# ..          ...           ...
# 195        86.0          15.6
# 196        52.0          24.6
# 197        84.0          11.6
# 198        79.0          18.6
# 199        82.0          19.4
#
# [398 rows x 2 columns]

# %%
df3 = df.loc[:, ["displacement", "acceleration"]]
df3
# Out:
#      displacement  acceleration
# 0             307          12.0
# 1             350          11.5
# 2             318          11.0
# 3             304          12.0
# 4             302          10.5
# ..            ...           ...
# 195           140          15.6
# 196            97          24.6
# 197           135          11.6
# 198           120          18.6
# 199           119          19.4
#
# [398 rows x 2 columns]

# %%
print(df1.head())
print(df2.head())
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0          8           307        130    3504          12.0     70
# 1  15.0          8           350        165    3693          11.5     70
# 2  18.0          8           318        150    3436          11.0     70
# 3  16.0          8           304        150    3433          12.0     70
# 4  17.0          8           302        140    3449          10.5     70
#
#    origin                        car
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  33.0          4            91         53    1795          17.4     76
# 1  20.0          6           225        100    3651          17.7     76
# 2  18.0          6           250         78    3574          21.0     76
# ...

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  model  \
# 0    18.0          8           307       130.0    3504          12.0     70
# 1    15.0          8           350       165.0    3693          11.5     70
# 2    18.0          8           318       150.0    3436          11.0     70
# 3    16.0          8           304       150.0    3433          12.0     70
# 4    17.0          8           302       140.0    3449          10.5     70
# ..    ...        ...           ...         ...     ...           ...    ...
# 195  27.0          4           140        86.0    2790          15.6     82
# 196  44.0          4            97        52.0    2130          24.6     82
# 197  32.0          4           135        84.0    2295          11.6     82
# 198  28.0          4           120        79.0    2625          18.6     82
# 199  31.0          4           119        82.0    2720          19.4     82
#
#      origin                        car
# ...

# %%
new_column = np.random.randint(10000, 50000, 398)
new_column
# Out:
# array([44216, 40608, 19525, 32157, 35123, 29978, 11178, 32703, 46622,
#        46324, 37458, 17261, 40749, 17351, 46647, 15027, 25916, 18290,
#        42934, 44778, 33133, 29180, 13595, 46486, 39638, 42740, 30144,
#        30925, 45850, 37625, 26278, 28525, 34787, 48934, 49723, 12538,
#        27046, 43425, 42046, 38512, 15199, 38982, 45462, 35733, 43856,
#        22163, 26856, 31171, 11818, 39380, 40049, 14157, 24740, 43491,
#        27230, 24602, 23636, 34245, 42681, 24832, 43901, 23351, 17053,
#        40957, 36879, 33930, 34970, 26763, 47807, 18137, 33276, 10107,
#        20760, 43729, 41731, 49721, 25358, 28740, 38647, 48674, 38470,
#        26250, 48267, 41977, 18201, 44593, 30557, 29008, 27284, 49292,
#        14503, 21774, 43164, 15116, 40544, 27527, 16494, 47606, 24633,
#        35001, 48536, 21744, 11979, 22229, 19190, 11557, 19632, 39230,
#        11441, 44605, 32685, 44580, 33211, 20454, 26756, 15711, 27001,
# ...

# %%
type(new_column)
# Out:
# numpy.ndarray

# %%
df["new"] = new_column

df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  model  \
# 0    18.0          8           307       130.0    3504          12.0     70
# 1    15.0          8           350       165.0    3693          11.5     70
# 2    18.0          8           318       150.0    3436          11.0     70
# 3    16.0          8           304       150.0    3433          12.0     70
# 4    17.0          8           302       140.0    3449          10.5     70
# ..    ...        ...           ...         ...     ...           ...    ...
# 195  27.0          4           140        86.0    2790          15.6     82
# 196  44.0          4            97        52.0    2130          24.6     82
# 197  32.0          4           135        84.0    2295          11.6     82
# 198  28.0          4           120        79.0    2625          18.6     82
# 199  31.0          4           119        82.0    2720          19.4     82
#
#      origin                        car    new
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 398 entries, 0 to 199
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    int64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model         398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car           398 non-null    object
#  9   new           398 non-null    int64
# dtypes: float64(3), int64(6), object(1)
# memory usage: 34.2+ KB
